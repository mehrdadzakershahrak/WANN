# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import glob
from tensorboard.backend.event_processing import event_accumulator

# %matplotlib inline

# %%
no_wann_mean_rewards = None
for i in range(20, 30):    
    NO_WANN_PATH =  f'C:{os.sep}Users{os.sep}Blake{os.sep}Desktop{os.sep}review{os.sep}result{os.sep}no-wann-sac-bipedalwalker-v3-{i}{os.sep}log{os.sep}monitor.csv'
    no_wann_df = pd.read_csv(NO_WANN_PATH, skiprows=1)
    
    if i == 20:
        no_wann_mean_rewards = no_wann_df['r']
    else:
        no_wann_mean_rewards += no_wann_df['r']

no_wann_mean_rewards /= 10.0

no_wann_std_devs = None
for i in range(20, 30):    
    NO_WANN_PATH =  f'C:{os.sep}Users{os.sep}Blake{os.sep}Desktop{os.sep}review{os.sep}result{os.sep}no-wann-sac-bipedalwalker-v3-{i}{os.sep}log{os.sep}monitor.csv'
    no_wann_df = pd.read_csv(NO_WANN_PATH, skiprows=1)
    
    if i == 20:
        no_wann_std_devs = (no_wann_df['r']-no_wann_mean_rewards)**2.0
    else:
        no_wann_std_devs += (no_wann_df['r']-no_wann_mean_rewards)**2.0

no_wann_std_devs /= 10.0
no_wann_std_devs = np.sqrt(no_wann_std_devs)

wann_mean_rewards = None
for i in range(20, 30):    
    W_WANN_PATH = f'C:{os.sep}Users{os.sep}Blake{os.sep}Desktop{os.sep}review{os.sep}result{os.sep}wann-sac-bipedalwalker-v3-{i}{os.sep}log{os.sep}monitor.csv'
    wann_alg_df = pd.read_csv(W_WANN_PATH, skiprows=1)
    
    if i == 20:
        wann_mean_rewards = wann_alg_df['r']
    else:
        wann_mean_rewards += wann_alg_df['r']

wann_mean_rewards /= 10
        
wann_std_devs = None
for i in range(20, 30):    
    W_WANN_PATH = f'C:{os.sep}Users{os.sep}Blake{os.sep}Desktop{os.sep}review{os.sep}result{os.sep}wann-sac-bipedalwalker-v3-{i}{os.sep}log{os.sep}monitor.csv'
    wann_alg_df = pd.read_csv(W_WANN_PATH, skiprows=1)
    
    if i == 20:
        wann_std_devs = (wann_alg_df['r']-wann_mean_rewards)**2.0
    else:
        wann_std_devs += (wann_alg_df['r']-wann_mean_rewards)**2.0

wann_std_devs /= 10
wann_std_devs = np.sqrt(wann_std_devs)

N_EPISODES = 500

x = range(N_EPISODES)

fig = plt.figure(figsize=(10,5))
ax = fig.add_axes([0,0,1,1])
ax.set_xlabel('Episode')
ax.set_ylabel('Mean Cumulative Reward')

plt.plot(x, no_wann_mean_rewards[:N_EPISODES], color='green', alpha=0.3, linewidth=2.0, label='Without WANN')
plt.fill_between(x, no_wann_mean_rewards[:N_EPISODES]-no_wann_std_devs[:N_EPISODES], 
                 no_wann_mean_rewards[:N_EPISODES]+no_wann_std_devs[:N_EPISODES],
                 facecolor='red', alpha=0.1)

plt.plot(x, wann_mean_rewards[:N_EPISODES], color='blue', alpha=0.3, linewidth=2.0, label='With WANN')
plt.fill_between(x, wann_mean_rewards[:N_EPISODES]-wann_std_devs[:N_EPISODES], 
                 wann_mean_rewards[:N_EPISODES]+wann_std_devs[:N_EPISODES],
                 facecolor='grey', alpha=0.1)


def set_style():
    plt.minorticks_on()
    plt.grid(b=True, which='minor', color='white', linestyle='-',
             alpha=0.4)
    plt.style.use('ggplot')
    plt.rcParams.update({'font.size': 22})
    legend=plt.gca().legend(bbox_to_anchor=(0.,1.02, 1., .102), loc=3, ncol=2, mode='expand',
                            borderaxespad=0., frameon=1)
    frame=legend.get_frame()
    frame.set_facecolor('white')
    frame.set_edgecolor('white')
    
set_style()

def save_fig(fn):
    plt.savefig(fn, dpi=321, facecolor='w', edgecolor='w', orientation='portrait', papertype=None,
                format=None, transparent=False, bbox_inches='tight', pad_inches=0.02, frameon=None,
                metadata=None)
    
save_fig('test.png')
# Out:
# c:\programdata\anaconda3\envs\drl-examples\lib\site-packages\ipykernel_launcher.py:88: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
# c:\programdata\anaconda3\envs\drl-examples\lib\site-packages\ipykernel_launcher.py:88: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-dc48a20f84a9> in <module>
#       1 # plot mean reward over episodes
#       2 W_WANN_PATH_TO_MONITOR = WITHOUT_WANN_PATH_TO_MONITOR = f'C:{os.sep}Users{os.sep}Blake{os.sep}Documents{os.sep}software_engineering{os.sep}research{os.sep}mehrdad{os.sep}WANN{os.sep}src{os.sep}result{os.sep}wann-sac-bipedalwalker-v3-18{os.sep}log{os.sep}monitor.csv'
# ----> 3 wann_alg_df = pd.read_csv(W_WANN_PATH_TO_MONITOR, skiprows=1)
#       4
#       5 no_wann_rewards = None
#
# ...

# %%
def load_tf(dirname):
    dirname = glob.glob(dirname + '/*/*')[0]
    
    ea = event_accumulator.EventAccumulator(dirname, size_guidance={event_accumulator.SCALARS: 0})
    ea.Reload()
    dframes = {}
    mnames = ea.Tags()['scalars']
    
    for n in mnames:
        print(ea.Scalars(n))
        
#         dframes[n] = pd.DataFrame(ea.Scalars(n), columns=["wall_time", "epoch", n.replace('val/', '')])
#         dframes[n].drop("wall_time", axis=1, inplace=True)
#         dframes[n] = dframes[n].set_index("epoch")
#     return pd.concat([v for k,v in dframes.items()], axis=1)

# %%
wann_tb_path = f'C:{os.sep}Users{os.sep}Blake{os.sep}Desktop{os.sep}prev-runs{os.sep}wann-sac-bipedalwalker-v3-1{os.sep}log{os.sep}tb-log'
wann_tb_df = load_tf(wann_tb_path)
# Out:
# [ScalarEvent(wall_time=1600680280.5753653, step=2382, value=1300.4000244140625)]
# [ScalarEvent(wall_time=1600680280.5753653, step=2382, value=-34.95099639892578)]
# [ScalarEvent(wall_time=1600680280.5753653, step=2382, value=238.1999969482422)]
# [ScalarEvent(wall_time=1600680280.5753653, step=2382, value=-104.22283935546875)]
# [ScalarEvent(wall_time=1600680280.5753653, step=2382, value=66.0)]
# [ScalarEvent(wall_time=1600680280.5753653, step=2382, value=-20.46751594543457)]
# [ScalarEvent(wall_time=1600680280.5753653, step=2382, value=5.240581512451172)]
# [ScalarEvent(wall_time=1600680280.5753653, step=2382, value=0.7972384691238403)]
# [ScalarEvent(wall_time=1600680280.5753653, step=2382, value=-1.4661630392074585)]
# [ScalarEvent(wall_time=1600680280.5753653, step=2382, value=9.999999747378752e-05)]
